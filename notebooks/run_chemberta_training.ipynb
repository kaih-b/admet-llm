# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install torch transformers datasets evaluate accelerate scikit-learn wandb
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 5.0 MB/s eta 0:00:00
# ...

# %%
import wandb
wandb.login()
# Out:
# True

# %%
# %cd "/content/drive/Othercomputers/My Mac/admet-llm"
# !env PYTHONPATH="." python3 src/models/train_chemberta.py
# Out:
# /content/drive/Othercomputers/My Mac/admet-llm
# 2026-03-21 01:08:34 - INFO - __main__ - Local environment detected
# 2026-03-21 01:08:34 - INFO - __main__ - Loading train, valid, and test datasets...
# 2026-03-21 01:08:34 - INFO - __main__ - Downloading tokenizer for DeepChem/ChemBERTa-77M-MTR...
# 2026-03-21 01:08:34 - INFO - __main__ - Tokenizing the datasets...
# Map: 100% 7640/7640 [00:01<00:00, 4016.74 examples/s]
# Map: 100% 955/955 [00:00<00:00, 4342.57 examples/s]
# Map: 100% 956/956 [00:00<00:00, 4150.78 examples/s]
# 2026-03-21 01:08:37 - INFO - __main__ - Loading pre-trained ChemBERTa model...
# ...
# Loading weights: 100% 53/53 [00:00<00:00, 5031.87it/s, Materializing param=roberta.encoder.layer.2.output.dense.weight]
# RobertaForSequenceClassification LOAD REPORT from: DeepChem/ChemBERTa-77M-MTR
# Key                             | Status     |
# --------------------------------+------------+-
# regression.dense.bias           | UNEXPECTED |
# ...
