# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install transformers datasets xgboost optuna accelerate tqdm
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 419.5/419.5 kB 14.7 MB/s eta 0:00:00
# ...

# %%
# %cd "/content/drive/Othercomputers/My Mac/admet-llm"
# !env PYTHONPATH="." python3 src/models/extract_embeddings.py
# Out:
# /content/drive/Othercomputers/My Mac/admet-llm
# 2026-03-21 18:10:04 - INFO - __main__ - Loading DeepChem/ChemBERTa-77M-MTR as a feature extractor...
# ...
# config.json: 17.7kB [00:00, 36.8MB/s]
# tokenizer_config.json: 1.27kB [00:00, 5.25MB/s]
# vocab.json: 6.96kB [00:00, 24.1MB/s]
# merges.txt: 100% 52.0/52.0 [00:00<00:00, 280kB/s]
# tokenizer.json: 8.26kB [00:00, 25.7MB/s]
# added_tokens.json: 100% 25.0/25.0 [00:00<00:00, 193kB/s]
# special_tokens_map.json: 100% 420/420 [00:00<00:00, 3.06MB/s]
# pytorch_model.bin: 100% 14.0M/14.0M [00:00<00:00, 15.6MB/s]
# Loading weights: 100% 53/53 [00:00<00:00, 4220.74it/s, Materializing param=encoder.layer.2.output.dense.weight]
# RobertaModel LOAD REPORT from: DeepChem/ChemBERTa-77M-MTR
# Key                             | Status     |
# --------------------------------+------------+-
# norm_mean                       | UNEXPECTED |
# norm_std                        | UNEXPECTED |
# regression.dense.weight         | UNEXPECTED |
# ...

# %%
# %cd "/content/drive/Othercomputers/My Mac/admet-llm"
# !env PYTHONPATH="." python3 src/models/optimize_hybrid.py
# Out:
# /content/drive/Othercomputers/My Mac/admet-llm
# 2026-03-21 18:23:50 - INFO - __main__ - Loading embeddings...
# 2026-03-21 18:23:53 - INFO - __main__ - Starting Optuna study...
# [I 2026-03-21 18:23:53,533] A new study created in memory with name: hybrid_xgboost_optimization
# /usr/local/lib/python3.12/dist-packages/xgboost/core.py:751: UserWarning: [18:24:00] WARNING: /__w/xgboost/xgboost/src/common/error_msg.cc:62: Falling back to prediction using DMatrix due to mismatched devices. This might lead to higher memory usage and slower performance. XGBoost is running on: cuda:0, while the input data is on: cpu.
# Potential solutions:
# - Use a data structure that matches the device ordinal in the booster.
# - Set the device for booster before call to inplace_predict.
#
# This warning will only be shown once.
#
#   return func(**kwargs)
# ...

# %%
# %cd "/content/drive/Othercomputers/My Mac/admet-llm"
# !env PYTHONPATH="." python3 src/models/train_hybrid.py
# Out:
# /content/drive/Othercomputers/My Mac/admet-llm
# 2026-03-21 19:18:59 - INFO - __main__ - Loading ChemBERTa embeddings...
# 2026-03-21 19:18:59 - INFO - __main__ - Found optimized parameters at models/hybrid/best_optuna_params.json. Loading...
# 2026-03-21 19:18:59 - INFO - __main__ - Initializing XGBoost Regressor with optimized parameters:
# 2026-03-21 19:18:59 - INFO - __main__ -   n_estimators: 1900
# 2026-03-21 19:18:59 - INFO - __main__ -   max_depth: 11
# 2026-03-21 19:18:59 - INFO - __main__ -   learning_rate: 0.012992289314216829
# 2026-03-21 19:18:59 - INFO - __main__ -   subsample: 0.6647956694015149
# 2026-03-21 19:18:59 - INFO - __main__ -   colsample_bytree: 0.7870322030111898
# 2026-03-21 19:18:59 - INFO - __main__ -   gamma: 0.11963935733250605
# 2026-03-21 19:18:59 - INFO - __main__ -   min_child_weight: 9
# 2026-03-21 19:18:59 - INFO - __main__ - Training Hybrid model...
# [0]	validation_0-rmse:0.86350
# [100]	validation_0-rmse:0.75663
# ...
