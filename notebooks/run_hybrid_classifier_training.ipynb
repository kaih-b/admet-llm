# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install datasets xgboost optuna accelerate tqdm scikit-learn
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 419.5/419.5 kB 14.1 MB/s eta 0:00:00
# ...

# %%
# %cd "/content/drive/Othercomputers/My Mac/admet-llm"
# !env PYTHONPATH="." python3 src/models/optimize_hybrid_classifier.py
# Out:
# /content/drive/Othercomputers/My Mac/admet-llm
# 2026-03-24 19:11:14 - INFO - __main__ - Loading data and binarizing labels (Threshold >= 5.0)...
# 2026-03-24 19:11:14 - INFO - __main__ - Loading ChemBERTa embeddings...
# 2026-03-24 19:11:14 - INFO - __main__ - Starting Optuna study for Classification...
# [I 2026-03-24 19:11:14,372] A new study created in memory with name: hybrid_classifier_optimization
# /usr/local/lib/python3.12/dist-packages/xgboost/core.py:751: UserWarning: [19:11:16] WARNING: /__w/xgboost/xgboost/src/common/error_msg.cc:62: Falling back to prediction using DMatrix due to mismatched devices. This might lead to higher memory usage and slower performance. XGBoost is running on: cuda:0, while the input data is on: cpu.
# Potential solutions:
# - Use a data structure that matches the device ordinal in the booster.
# - Set the device for booster before call to inplace_predict.
#
# This warning will only be shown once.
#
#   return func(**kwargs)
# ...

# %%
# %cd "/content/drive/Othercomputers/My Mac/admet-llm"
# !env PYTHONPATH="." python3 src/models/train_hybrid_classifier.py
# Out:
# /content/drive/Othercomputers/My Mac/admet-llm
# 2026-03-24 19:52:49 - INFO - __main__ - Binarizing labels with pIC50 Threshold: 5.0 (>= 5.0 is Toxic)
# 2026-03-24 19:52:49 - INFO - __main__ - Loading original CSVs for labels...
# 2026-03-24 19:52:49 - INFO - __main__ - Loading ChemBERTa embeddings...
# 2026-03-24 19:52:49 - INFO - __main__ - Initializing XGBoost Classifier with optimized parameters:
# 2026-03-24 19:52:49 - INFO - __main__ -   n_estimators: 1200
# 2026-03-24 19:52:49 - INFO - __main__ -   max_depth: 9
# 2026-03-24 19:52:49 - INFO - __main__ -   learning_rate: 0.03725922366552288
# 2026-03-24 19:52:49 - INFO - __main__ -   subsample: 0.7065653901144676
# 2026-03-24 19:52:49 - INFO - __main__ -   colsample_bytree: 0.8657378695838699
# 2026-03-24 19:52:49 - INFO - __main__ -   gamma: 1.4856871343921185
# 2026-03-24 19:52:49 - INFO - __main__ -   min_child_weight: 2
# [0]	validation_0-auc:0.62054
# [100]	validation_0-auc:0.74816
# [200]	validation_0-auc:0.76128
# ...
